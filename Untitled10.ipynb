# %%
def print_board(board):
    for row in board:
        print(" | ".join(row))
        print("-" * 9)

def get_move(board, player):
    while True:
        try:
            row = int(input(f"Player {player}, enter the row number (0, 1, or 2): "))
            col = int(input(f"Player {player}, enter the column number (0, 1, or 2): "))

            if board[row][col] == "":
                return row, col
            else:
                print("That square is already taken. Try again.")
        except (ValueError, IndexError):
            print("Invalid input. Please enter valid row and column numbers.")

def check_win(board, player):
    # Check rows
    for row in board:
        if all(square == player for square in row):
            return True

    # Check columns
    for col in range(3):
        if all(board[row][col] == player for row in range(3)):
            return True

    # Check diagonals
    if all(board[i][i] == player for i in range(3)) or all(board[i][2 - i] == player for i in range(3)):
        return True

    return False

def check_tie(board):
    for row in board:
        for square in row:
            if square == "":
                return False
    return True

def tic_tac_toe():
    players = ["X", "O"]
    player_index = 0

    # Initialize an empty 3x3 game board
    board = [["" for _ in range(3)] for _ in range(3)]

    while True:
        current_player = players[player_index]
        print_board(board)
        row, col = get_move(board, current_player)
        board[row][col] = current_player

        if check_win(board, current_player):
            print_board(board)
            print(f"Congratulations, Player {current_player} wins!")
            break

        if check_tie(board):
            print_board(board)
            print("It's a tie!")
            break

        player_index = (player_index + 1) % 2

if __name__ == "__main__":
    tic_tac_toe()
# Out:
#  |  |
# ---------
#  |  |
# ---------
#  |  |
# ---------
# Player X, enter the row number (0, 1, or 2): 0
# Player X, enter the column number (0, 1, or 2): 1
#  | X |
# ---------
#  |  |
# ---------
#  |  |
# ---------
# Player O, enter the row number (0, 1, or 2): 2
# Player O, enter the column number (0, 1, or 2): 0
#  | X |
# ---------
#  |  |
# ---------
# O |  |
# ---------
# Player X, enter the row number (0, 1, or 2): 1
# Player X, enter the column number (0, 1, or 2): 2
#  | X |
# ---------
#  |  | X
# ---------
# O |  |
# ---------
# Player O, enter the row number (0, 1, or 2): 1
# Player O, enter the column number (0, 1, or 2): 2
# That square is already taken. Try again.
# Player O, enter the row number (0, 1, or 2): 2
# Player O, enter the column number (0, 1, or 2): 2
#  | X |
# ---------
#  |  | X
# ---------
# O |  | O
# ---------
# Player X, enter the row number (0, 1, or 2): 0
# Player X, enter the column number (0, 1, or 2): 0
# X | X |
# ---------
#  |  | X
# ---------
# O |  | O
# ---------
# Player O, enter the row number (0, 1, or 2): 0
# Player O, enter the column number (0, 1, or 2): 0
# That square is already taken. Try again.
# Player O, enter the row number (0, 1, or 2): 0
# Player O, enter the column number (0, 1, or 2): 0
# That square is already taken. Try again.
# Player O, enter the row number (0, 1, or 2): 0
# Player O, enter the column number (0, 1, or 2): 0
# That square is already taken. Try again.
# Player O, enter the row number (0, 1, or 2): 0
# Player O, enter the column number (0, 1, or 2): 0
# That square is already taken. Try again.
